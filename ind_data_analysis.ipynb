# %% [markdown]
# # Individual sector data analysis
# This book looks at each sector individually

# %%
# from tools import get_mutual_fund_data, get_bond_data, get_ff_data, get_index_data
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
# from data_tools import capm, ff_3, ff_5, reg_date_range, capm_index, corr_index
from ind_data_tools import data_analyze_strat_base, data_analyze_strat_bench, data_analyze_strat_5, data_analyze_top
# Out:
# Total number of categories 20
# Total number of funds: 1698
#
# Mutual Fund Data
# c:\Users\dklro\Documents\Fall 2023\15.433\15-4331-final-project\tools.py:129: DtypeWarning: Columns (3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data/mutual_funds/mutual_fund_data.csv",skiprows=0).dropna(how='any')
# Total number of rows: 408031
# Total number of funds with enough data: 1608
# Funds with no data: 25
# Funds with less than 5 years of data: 65
# Columns: Index(['ticker', 'date', 'total_net_assets', 'total_returns',
#        'net_asset_value', 'nav_return'],
#       dtype='object')
#
# Mutual Fund Data
# c:\Users\dklro\Documents\Fall 2023\15.433\15-4331-final-project\tools.py:129: DtypeWarning: Columns (3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data/mutual_funds/mutual_fund_data.csv",skiprows=0).dropna(how='any')
# Total number of rows: 408031
# ...

# %%
def analyze(strat, strat_name):
    data_analyze_strat_base(strat, strat_name)
    data_analyze_strat_bench(strat, strat_name)
    data_analyze_strat_5(strat, strat_name)
    data_analyze_top(strat, strat_name)

# %% [markdown]
# ### Large Value

# %%
analyze(0, 'Large Value')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['LBSAX', 'MEIAX', 'IAUTX', 'HDGCX', 'NPNCX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['AMFCX', 'AMFFX', 'MEIAX', 'LBSAX', 'LBSCX', 'IHGIX', 'HDGCX', 'NPNCX', 'PARWX', 'DDVAX', 'IAUTX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['VWNDX', 'MSDVX', 'FEQTX', 'OAYLX', 'LAFFX', 'TCLCX', 'ACGIX', 'OLVAX', 'OLVCX', 'HLQVX', 'FFEIX', 'FFECX', 'SAIFX']
# Average beta of below stdev alpha is 0.9521717152658417 with a stdev on beta of 0.11186015059528046
# Average beta of above stdev alpha is 0.8261711233636543 with a stdev on beta of 0.11280703987442978
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['IAUTX', 'SVFFX', 'PARWX', 'OAYMX', 'NPNCX'].  Note last one is best one
# ...

# %% [markdown]
# ### Large Blend

# %%
analyze(1, 'Large Blend')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['HAIAX', 'AFDCX', 'AFDIX', 'AFEIX', 'AFDAX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['VDIGX', 'FRDPX', 'FRDTX', 'PRDGX', 'JENSX', 'HAIAX', 'HGICX', 'HGIIX', 'NSBAX', 'NSBCX', 'HCACX', 'AFDAX', 'AFDCX', 'AFEIX', 'AFDIX', 'AUENX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['SHAPX', 'PCODX', 'PIORX', 'PYODX', 'MITTX', 'NYVCX', 'ITHIX', 'SAGYX', 'DSEEX', 'DSENX', 'SUWIX', 'CHTRX', 'CHTCX', 'OARDX', 'OCRDX']
# Average beta of below stdev alpha is 0.9736938594488289 with a stdev on beta of 0.09460205640928213
# Average beta of above stdev alpha is 0.8842267730187563 with a stdev on beta of 0.08924164395402252
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['HAIAX', 'AFDCX', 'AFDIX', 'AFEIX', 'AFDAX'].  Note last one is best one
# ...

# %% [markdown]
# ### Large Growth

# %%
analyze(2, 'Large Growth')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['JGASX', 'BAWAX', 'BIAWX', 'AKREX', 'AKRIX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['TRBCX', 'EGFIX', 'EGFFX', 'VHIAX', 'JGASX', 'AKRIX', 'AKREX', 'SBLYX', 'BAWAX', 'BIAWX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['VWUSX', 'FMAGX', 'MLACX', 'TWRCX', 'MIGFX', 'FDCAX', 'PNOCX', 'MSGUX']
# Average beta of below stdev alpha is 1.0972052368908125 with a stdev on beta of 0.07416806500037568
# Average beta of above stdev alpha is 1.004575649415722 with a stdev on beta of 0.08770503727885975
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['CEYIX', 'BIAWX', 'TRBCX', 'AKREX', 'AKRIX'].  Note last one is best one
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['TRBCX', 'FRGSX', 'VHIAX', 'AKRIX', 'AKREX', 'SBLYX', 'BAWAX', 'BIAWX', 'CEYIX', 'WLGAX']
# ...

# %% [markdown]
# ### Mid-Cap Value

# %%
analyze(3, 'Mid-Cap Value')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['MCVIX', 'JAMCX', 'FTVNX', 'FACSX', 'FTVSX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['MVCAX', 'MVCCX', 'MCVIX', 'TRMCX', 'JAMCX', 'JCMVX', 'VASVX', 'PRNIX', 'IIVAX', 'CIMDX', 'FACSX', 'FTVSX', 'FTVNX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['ACCLX', 'CMUAX', 'SMVFX', 'JMCVX', 'MVTIX', 'PMDDX', 'HMVJX', 'FCBSX', 'PCCGX', 'FIVUX', 'SEVPX', 'ABMIX']
# Average beta of below stdev alpha is 1.0512551445681964 with a stdev on beta of 0.09195902836784105
# Average beta of above stdev alpha is 0.9948056008648496 with a stdev on beta of 0.07913024294102472
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['MAIMX', 'WFPAX', 'CIMDX', 'FTVNX', 'FTVSX'].  Note last one is best one
# ...

# %% [markdown]
# ### Mid-Cap Blend

# %%
analyze(4, 'Mid-Cap Blend')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['ETADX', 'EISMX', 'TMAPX', 'TMCTX', 'TMPIX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['EAASX', 'EISMX', 'TMAPX', 'TMCJX', 'TMCTX', 'TMPIX', 'JSVAX', 'ETADX', 'ETCDX', 'ETIDX', 'ETNDX', 'TVAFX', 'TVIFX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['SCSAX', 'STSAX', 'HFCIX', 'HFCSX', 'DNLCX', 'DVLCX', 'MCSPX', 'ODMCX', 'GVCAX', 'GVCCX']
# Average beta of below stdev alpha is 1.1109137020835562 with a stdev on beta of 0.060320884915609926
# Average beta of above stdev alpha is 0.9412495185252518 with a stdev on beta of 0.07245125086459556
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['ETCDX', 'ETNDX', 'ETIDX', 'ETADX', 'TMPIX'].  Note last one is best one
# ...

# %% [markdown]
# ### Mid-Cap Growth
# Seems to be an issue with DEEVX here cause the actual alpha is more like -5.

# %%
analyze(5, 'Mid-Cap Growth')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['VMACX', 'VIMCX', 'VKSIX', 'ETGLX', 'LIACX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['POAGX', 'HAGAX', 'ETILX', 'ETGLX', 'LCLAX', 'LIACX', 'PEGCX', 'VMACX', 'VMCCX', 'VIMCX', 'VKSIX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['HFMIX', 'KAUIX', 'FRSIX', 'LACAX', 'CHCLX', 'CHCCX', 'PEGEX', 'GOFCX', 'TQMIX']
# Average beta of below stdev alpha is 1.0942644775117927 with a stdev on beta of 0.0924284224786975
# Average beta of above stdev alpha is 1.0513607839044197 with a stdev on beta of 0.11018010245786075
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['VMACX', 'ETGLX', 'LCLAX', 'VIMCX', 'VKSIX'].  Note last one is best one
# ...

# %% [markdown]
# ### Small Value

# %%
analyze(6, 'Small Value')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['BRSVX', 'VSCAX', 'BPSCX', 'BPSIX', 'AVALX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['VSCAX', 'BPSIX', 'BPSCX', 'BRSVX', 'HRVIX', 'AVALX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['ABSAX', 'MCVSX', 'GSATX', 'GSCTX', 'HFMDX', 'TRACX', 'PSVDX']
# Average beta of below stdev alpha is 1.3066776677778023 with a stdev on beta of 0.09733466905405097
# Average beta of above stdev alpha is 1.089811564282951 with a stdev on beta of 0.11571727707223356
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['UBVCX', 'UBVAX', 'AVALX', 'BRSVX', 'SCVNX'].  Note last one is best one
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['UBVAX', 'UBVCX', 'HIMDX', 'BRSVX', 'SCVNX', 'AVALX', 'LSVQX', 'DRSVX']
# ...

# %% [markdown]
# ### Small Blend

# %%
analyze(7, 'Small Blend')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['VSEAX', 'FOSCX', 'STMSX', 'PRSVX', 'WMCVX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['PRSVX', 'VSEAX', 'WMCVX', 'STMSX', 'FOSCX', 'RPMFX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['PCKAX', 'PCKCX', 'PSNSX', 'NEJCX', 'VVPSX']
# Average beta of below stdev alpha is 1.2734658443293643 with a stdev on beta of 0.07630000646892514
# Average beta of above stdev alpha is 0.9978849535292098 with a stdev on beta of 0.0896780475336682
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['OSCAX', 'WICVX', 'WMCVX', 'SZCIX', 'RPMFX'].  Note last one is best one
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['JCCIX', 'OSCAX', 'OSCCX', 'WMCVX', 'WICVX', 'SZCIX', 'GWEIX', 'RPMFX']
# ...

# %% [markdown]
# ### Small Growth

# %%
analyze(8, 'Small Growth')
# Out:
# CAPM base measurement
# The largest alpha funds by CAPM marked to whole market are ['DNSMX', 'PSCCX', 'WBSIX', 'NBGIX', 'NBGNX'].  Note that the best one is last.
# The mutual funds that are 1 stdev above mean with benchmark alpha are ['NBGIX', 'NBGNX', 'NBGEX', 'PRDSX', 'FKAIX', 'WGROX', 'BCSIX', 'PSCCX', 'ANOIX', 'WBSIX', 'WBSNX', 'DNSMX', 'DVSMX']
# The mutual funds that are 1 stdev below mean with benchmark alpha are ['PSCHX', 'WIAEX', 'CGOAX', 'MRAGX', 'HISGX', 'IHSIX', 'HSCCX', 'CSGEX', 'VLEIX', 'WSMCX']
# Average beta of below stdev alpha is 1.1898018960064203 with a stdev on beta of 0.07839364312910213
# Average beta of above stdev alpha is 1.0778922305407126 with a stdev on beta of 0.11987925691718818
# CAPM benchmark measurement
# The largest alpha funds by CAPM marked to benchmask are ['NBGNX', 'PSCCX', 'FKAIX', 'DVSMX', 'DNSMX'].  Note last one is best one
# ...
